# %%
# import packages 
import pandas as pd                   # data management
import matplotlib.pyplot as plt       # graphics 
import datetime as dt                 # check today's date 
import sys                            # check Python version 

# IPython command, puts plots in notebook 
# %matplotlib inline

print('Today is', dt.date.today())
print('Python version:\n', sys.version, sep='') ## Question 0
# Out:
# Today is 2017-12-07
# Python version:
# 3.6.2 |Anaconda, Inc.| (default, Sep 21 2017, 18:29:43)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
url = 'https://raw.githubusercontent.com/chrisc617/Data-Bootcamp-Final-Project/master/rollingsales_manhattan%20(1).csv'
nyc_property = pd.read_csv(url, sep=',')
nyc_property.head()
# Out:
#   Manhattan Rolling Sales File.  All Sales From November 2016 - October 2017.  \
# 0  Sales File as of 11/9/2017  Co-op Sales Files ...
# 1  Neighborhood Names and Descriptive Data as of ...
# 2  Building Class Category is based on Building C...
# 3                                            BOROUGH
# 4                                                  1
#
#                   Unnamed: 1                                    Unnamed: 2  \
# 0                        NaN                                           NaN
# 1                        NaN                                           NaN
# 2                        NaN                                           NaN
# 3               NEIGHBORHOOD                       BUILDING CLASS CATEGORY
# 4  ALPHABET CITY              03  THREE FAMILY DWELLINGS
#
#              Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                   NaN        NaN        NaN        NaN
# 1                   NaN        NaN        NaN        NaN
# 2                   NaN        NaN        NaN        NaN
# 3  TAX CLASS AT PRESENT      BLOCK        LOT  EASE-MENT
# 4                     1        376         24
#
#                   Unnamed: 7                                 Unnamed: 8  \
# 0                        NaN                                        NaN
# 1                        NaN                                        NaN
# 2                        NaN                                        NaN
# 3  BUILDING CLASS AT PRESENT                                    ADDRESS
# 4                         C0  264 EAST 7TH   STREET
#
#          Unnamed: 9     ...            Unnamed: 11       Unnamed: 12  \
# 0               NaN     ...                    NaN               NaN
# 1               NaN     ...                    NaN               NaN
# 2               NaN     ...                    NaN               NaN
# 3  APARTMENT NUMBER     ...      RESIDENTIAL UNITS  COMMERCIAL UNITS
# 4                       ...                      3                 0
#
#    Unnamed: 13       Unnamed: 14        Unnamed: 15 Unnamed: 16  \
# 0          NaN               NaN                NaN         NaN
# 1          NaN               NaN                NaN         NaN
# 2          NaN               NaN                NaN         NaN
# 3  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT
# 4            3            2,059              3,696         1900
#
#                  Unnamed: 17                     Unnamed: 18   Unnamed: 19  \
# 0                        NaN                             NaN           NaN
# 1                        NaN                             NaN           NaN
# 2                        NaN                             NaN           NaN
# 3  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE   SALE PRICE
# 4                          1                              C0    7,738,700
#
#   Unnamed: 20
# 0         NaN
# 1         NaN
# 2         NaN
# 3   SALE DATE
# 4  12/22/2016
#
# [5 rows x 21 columns]

# %%
url = 'https://github.com/zhicheryl/Data-Bootcamp-Final-Project/raw/master/NYC_Health_and_Hospitals_Corporation_Facilities.csv'
health_center = pd.read_csv(url, sep=',')
health_center.head()
hc=health_center
hc.head()
hc.dropna()
hc=hc.dropna()
hc.head()
hc.columns=[i.lower() for i in hc.columns]
hc.drop(hc[['cross streets','phone','location 1','community board','council district','bin']],axis=1)
hc=hc.drop(hc[['cross streets','phone','location 1','community board','council district','bin']],axis=1)
names = list(hc)
hc.rename(columns={names[3]: 'zipcode'})
hc=hc.rename(columns={names[3]: 'zipcode'})
hc.dtypes
hc[['zipcode','census tract']] = hc[['zipcode','census tract']].astype(int).astype(str)

# %%
hc.head()
# Out:
#           facility type    borough  \
# 8   Child Health Center  Manhattan
# 9   Child Health Center     Queens
# 15  Child Health Center   Brooklyn
# 25  Child Health Center  Manhattan
# 26  Child Health Center   Brooklyn
#
#                                    facility name zipcode   latitude  \
# 8             Drew Hamilton Houses Health Center   10030  40.821706
# 9                     Parsons Communicare Clinic   11432  40.703826
# 15             Sutter Avenue Child Health Clinic   11208  40.671892
# 25               Smith Communicare Health Center   10038  40.712019
# 26  Jonathan Williams Houses Child Health Clinic   11211  40.715381
#
#     longitude census tract           bbl  \
# 8  -73.942730          232  1.020290e+09
# 9  -73.800483        44601  4.097560e+09
# 15 -73.878197         1194  3.040390e+09
# 25 -73.997309           25  1.001110e+09
# 26 -73.956135          519  3.023370e+09
#
#                                                   nta
# 8   Central Harlem North-Polo Grounds             ...
# 9   Jamaica                                       ...
# 15  East New York                                 ...
# 25  Chinatown                                     ...
# 26  North Side-South Side                         ...

# %%
import folium as fm
map_hc = fm.Map(location=[34.088537, -118.249923],
                   zoom_start=9)
# for label in kmeans.cluster_centers_:
#     folium.Marker(location=[label][0]).add_to(map_2)

map_hc

# from sklearn.cluster import MiniBatchKMeans
# kmeans = MiniBatchKMeans(n_clusters=120, batch_size=1000).fit(geo_df[['latitude','longitude']])
# geo_df.loc[:, 'label'] = kmeans.labels_
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-181644a26ce4> in <module>()
# ----> 1 import folium as fm
#       2 map_hc = fm.Map(location=[34.088537, -118.249923],
#       3                    zoom_start=9)
#       4 # for label in kmeans.cluster_centers_:
#       5 #     folium.Marker(location=[label][0]).add_to(map_2)
#
# ModuleNotFoundError: No module named 'folium'

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim()

location = geolocator.reverse("40.70873961, -73.95942528")

print(location.address)
#Potsdamer Platz, Mitte, Berlin, 10117, Deutschland, European Union
print((location.latitude, location.longitude))
#(52.5094982, 13.3765983)
print(location.raw)
